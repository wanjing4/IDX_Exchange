# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np

# %% [markdown]
# # explanatory analysis
# Load data CRMLSListing202602.csv
# Load data CRMLSSold202602

# %%
df_listing = pd.read_csv("data/listing/CRMLSListing202602.csv")
print(df_listing.head()) # First 5 rows
# Out:
#    OriginalListPrice  ListingKey   CloseDate  ClosePrice ListAgentFirstName  \
# 0           499000.0  1156818465         NaN         NaN           Keersten
# 1             5500.0  1156816107         NaN         NaN           Nicholas
# 2          1195000.0  1156812825         NaN         NaN              David
# 3           675000.0  1156808971         NaN         NaN              Mario
# 4          1235000.0  1156807420  2026-04-03   1235000.0              Ariel
#
#   ListAgentLastName   Latitude   Longitude            UnparsedAddress  \
# 0            Milson  33.976312 -116.522054        65352 Rolling Hills
# 1            Cosfol  34.131821 -118.340211  3121 Lake Hollywood Drive
# 2            Duncan  33.485133 -117.681863       25692 Paseo Colonial
# 3           Garduno  32.615724 -117.045186           1221 Melrose Ave
# 4            Belkin  34.092963 -118.337298             6737 W Hepburn
#
#        PropertyType  ...  MainLevelBedrooms  NewConstructionYN  GarageSpaces  \
# 0       Residential  ...                4.0              False           2.0
# 1  ResidentialLease  ...                NaN                NaN           1.0
# 2       Residential  ...                0.0              False           2.0
# 3       Residential  ...                NaN              False           0.0
# 4       Residential  ...                0.0              False           2.0
#
#      HighSchoolDistrict PostalCode          BuyerOfficeName.1 AssociationFee  \
# 0  Palm Springs Unified      92240                        NaN            0.0
# 1                   NaN      90068                        NaN            0.0
# 2    Capistrano Unified      92675                        NaN          130.0
# 3                   NaN      91911                        NaN            NaN
# 4   Los Angeles Unified      90038  The One Luxury Properties          350.0
#
#   LotSizeSquareFeet MiddleOrJuniorSchoolDistrict          UnparsedAddress.1
# 0            9148.0                          NaN        65352 Rolling Hills
# 1            7543.0                          NaN  3121 Lake Hollywood Drive
# 2            2420.0                          NaN       25692 Paseo Colonial
# 3               NaN                          NaN           1221 Melrose Ave
# 4            1814.0                          NaN             6737 W Hepburn
#
# [5 rows x 81 columns]

# %%
print(df_listing.shape) # shape of listing
# Out:
# (31689, 81)

# %%
df_sold = pd.read_csv("data/sold/CRMLSSold202602.csv")
print(df_sold.head())# First 5 rows of sold
# Out:
#            BuyerAgentAOR           ListAgentAOR     Flooring ViewYN  \
# 0             HighDesert             HighDesert          NaN  False
# 1            ContraCosta                BayEast          NaN    NaN
# 2           OrangeCounty           OrangeCounty  Carpet,Tile  False
# 3  BeverlyHillsGreaterLa  BeverlyHillsGreaterLa         Wood  False
# 4               SanDiego               SanDiego          NaN    NaN
#
#   WaterfrontYN BasementYN PoolPrivateYN  OriginalListPrice  ListingKey  \
# 0          NaN        NaN         False          1850000.0  1156290692
# 1          NaN        NaN           NaN          1580000.0  1155696412
# 2          NaN        NaN         False          1100000.0  1155620121
# 3          NaN        NaN         False           999000.0  1155350576
# 4          NaN        NaN           NaN          1650000.0  1155221012
#
#     CloseDate  ...  MainLevelBedrooms NewConstructionYN GarageSpaces  \
# 0  2026-02-26  ...                NaN             False         20.0
# 1  2026-02-19  ...                NaN               NaN          NaN
# 2  2026-02-27  ...                3.0             False          2.0
# 3  2026-02-27  ...                NaN             False          NaN
# 4  2026-02-14  ...                NaN               NaN          NaN
#
#    HighSchoolDistrict  PostalCode AssociationFee LotSizeSquareFeet  \
# 0                 NaN       92307            0.0           29698.0
# 1                 NaN       95821            0.0           18682.0
# 2      Irvine Unified       92604            NaN            5000.0
# 3                 NaN       91411            NaN           12005.0
# 4                 NaN       91910            0.0            6851.0
#
#    MiddleOrJuniorSchoolDistrict  OriginatingSystemName  \
# 0                           NaN                  CRMLS
# 1                           NaN                  CRMLS
# 2                           NaN                  CRMLS
# 3                           NaN                  CRMLS
# 4                           NaN                  CRMLS
#
#    OriginatingSystemSubName
# 0                 CRMLS_CRM
# 1                CRMLS_CCBE
# 2                 CRMLS_CRM
# 3                  CRMLS_CL
# 4                CRMLS_SAND
#
# [5 rows x 79 columns]

# %%
print(df_sold.shape) # shape of sold
# Out:
# (19092, 79)

# %% [markdown]
# ## Check Missing

# %%
missing_pct = df_listing.isnull().sum() / df_listing.shape[0] *100
missing_df = missing_pct.reset_index()
missing_df.columns = ["column", "percent_missing"]
missing_df = missing_df.sort_values("percent_missing", ascending=False) # sort from high to low
# plot
plt.figure(figsize=(10, 8))
ax = sns.barplot(data=missing_df, y="column", x="percent_missing", hue = "column", palette = "Blues_r")

# add text labels
for i, v in enumerate(missing_df["percent_missing"]):
    ax.text(v + 0.5, i, f"{v:.1f}%", va="center", fontsize=9)

plt.xlabel("Percent Missing (%)")
plt.ylabel("Columns")
plt.title("Percent Missing by Column for Feb 2026 Listings ")
plt.yticks(fontsize=8)
plt.tight_layout()
plt.show()

# %%
missing_pct = df_sold.isnull().sum() / df_sold.shape[0] *100
missing_df = missing_pct.reset_index()
missing_df.columns = ["column", "percent_missing"]
missing_df = missing_df.sort_values("percent_missing", ascending=False) # sort from high to low
# plot
plt.figure(figsize=(10, 8))
ax = sns.barplot(data=missing_df, y="column", x="percent_missing", hue = "column", palette = "Blues_r")

# add text labels
for i, v in enumerate(missing_df["percent_missing"]):
    ax.text(v + 0.5, i, f"{v:.1f}%", va="center", fontsize=9)

plt.xlabel("Percent Missing (%)")
plt.ylabel("Columns")
plt.title("Percent Missing by Column for Feb 2025 Sold")
plt.yticks(fontsize=8)
plt.tight_layout()
plt.show()

# %% [markdown]
# The categories with less missing percent is probably more important for people who wants to buy the listing.
